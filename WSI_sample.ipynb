# %% [markdown]
# # WSI inference sample code
#
# - 주의할 점
#     - input dir에 여러 장이 있으면 한꺼번에 돕니다.
#     - 하지만 이럴 경우 temp dir을 공유하게 되는데 그럼 생성되는 json파일이 누적되게 됩니다.
#     - 따라서, input은 한장한장을 directory별로 나누어 입력하고 temp dir도 구별해주어야 합니다. (output은 directory를 하나 만들어주기에 따로 생성해줄 필요는 없습니다.)

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2
import math
import openslide as ops
import os
import json

from hover.postproc import process_utils as proc_utils
from hover.misc.wsi_handler import get_wsi_handler
from hover.misc.utils import visualize_instances
from run import InferWSI

# %%
args = {}

args['--gpu'] = '1'                  
args['--batch_size'] = 40           
args['--mode'] = 'wsi'
args['--inf_tile_shape'] = 10000     
args['--proc_tile_shape'] = 4096
args['--return_probs'] = False
args['--model'] = 'weight/pannuke.npz'
args['--input_dir'] = 'WSI/WSI_input/test_col_19'
args['--output_dir'] = 'WSI/WSI_output'
args['--cache_dir'] = 'WSI/WSI_temp/test_col_19' 
args['--postproc_workers'] = 20

# %%
infer_pannuke = InferWSI()
infer_pannuke._parse_args(args)
infer_pannuke.load_model()
infer_pannuke.load_filenames()
infer_pannuke.process_all_files()
# Out:
# Loading Model...
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# /data/hovernet_inference/WSI/WSI_input/test_col_19/Col_PNI2021chall_test_0019.svs
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ...
